# %% [markdown]
# <a href="https://colab.research.google.com/github/Josetob246/Veramo-IA/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importar librerias

# %% [markdown]
# Mariana Camacho Castro
# 2121763
# Jose Luis Tobias Hinojosa
# 1992178

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Dataset

# %%
(train_data, train_labels), (test_data, test_labels) = mnist.load_data()

print("Training images:", train_data.shape)
print("Training labels:", train_labels.shape)

print("Testing images:", test_data.shape)
print("Testing labels:", test_labels.shape)
# Out:
# Training images: (60000, 28, 28)
# Training labels: (60000,)
# Testing images: (10000, 28, 28)
# Testing labels: (10000,)

# %% [markdown]
# Imagen ejemplo

# %%
plt.imshow(train_data[0], cmap="gray")
plt.title(f"Label: {train_labels[0]}")
plt.axis("off")
plt.show()

# %% [markdown]
# preprocesamiento

# %% [markdown]
# normalizar

# %%
train_data = train_data.astype("float32") / 255.0
test_data = test_data.astype("float32") / 255.0

# %% [markdown]
# labels/format

# %%
train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)

# %% [markdown]
# seleccion de modelo

# %%
model = Sequential([
    Flatten(input_shape=(28,28)),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# %% [markdown]
# complilacion

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# Entrenamiento

# %%
history = model.fit(
    train_data,
    train_labels,
    epochs=10,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9275 - loss: 0.2367 - val_accuracy: 0.9632 - val_loss: 0.1157
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9697 - loss: 0.0976 - val_accuracy: 0.9703 - val_loss: 0.0944
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9784 - loss: 0.0695 - val_accuracy: 0.9745 - val_loss: 0.0861
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9839 - loss: 0.0516 - val_accuracy: 0.9708 - val_loss: 0.0999
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9862 - loss: 0.0441 - val_accuracy: 0.9739 - val_loss: 0.0956
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9890 - loss: 0.0344 - val_accuracy: 0.9695 - val_loss: 0.1255
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9899 - loss: 0.0306 - val_accuracy: 0.9784 - val_loss: 0.0925
# Epoch 8/10
# ...

# %%
print(f"Training Accuracy: {history.history['accuracy'][-1]*100:.2f}%")
print(f"Validation Accuracy: {history.history['val_accuracy'][-1]*100:.2f}%")
# Out:
# Training Accuracy: 99.33%
# Validation Accuracy: 97.61%

# %% [markdown]
# Evaluar

# %%
loss, accuracy = model.evaluate(test_data, test_labels)

print("Loss:", loss)
print("Accuracy:", accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9768 - loss: 0.1012
# Loss: 0.10118140280246735
# Accuracy: 0.9768000245094299

# %%
loss, accuracy = model.evaluate(test_data, test_labels)

print(f"Test Accuracy: {accuracy*100:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9768 - loss: 0.1012
# Test Accuracy: 97.68%

# %% [markdown]
# 5 predicts

# %%
predictions = model.predict(test_data)

for i in range(5):

    predicted = np.argmax(predictions[i])
    actual = np.argmax(test_labels[i])

    plt.imshow(test_data[i], cmap="gray")
    plt.title(f"Prediction: {predicted} | Actual: {actual}")
    plt.axis("off")
    plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# grafica

# %%
plt.plot(history.history["accuracy"], label="Training")
plt.plot(history.history["val_accuracy"], label="Validation")

plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.show()

# %% [markdown]
# perdida

# %%
plt.plot(history.history["loss"], label="Training")
plt.plot(history.history["val_loss"], label="Validation")

plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.show()
